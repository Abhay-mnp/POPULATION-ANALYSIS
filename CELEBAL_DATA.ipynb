# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay-mnp/POPULATION-ANALYSIS/blob/main/CELEBAL_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AIM : - ANALYSE DATA REGARDING PLACEMENTS FOR XYZ COMPANY FIND TOP STUDENTS BASED ON CERTAIN CRITERIA AND SHORTLIST THEM FOR FURTHER PROCEDURE OF PLACEMENTS

# %%
import pandas as pd
import numpy as np
import datetime as dt


student = pd.read_csv("/content/Registration  - Celebal Technologies (Responses) (4) (1).csv")

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 20 columns):
#  #   Column                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                            --------------  -----
#  0   Timestamp                                                                                                         45 non-null     object
#  1   Enrollment No.                                                                                                    45 non-null     object
#  2   Student Name                                                                                                      45 non-null     object
#  3   Course Name                                                                                                       45 non-null     object
# ...

# %%
student.head()
# Out:
#            Timestamp Enrollment No.     Student Name  Course Name   \
# 0  9/8/2023 16:39:07   A60205220099  Pradhumn Mittal    B.Tech-CSE
# 1  9/8/2023 17:40:38   A60205220141   Abhishek Mishra   B.Tech-CSE
# 2  9/8/2023 17:50:23   A60205220095    Shashank Dixit   B.Tech-CSE
# 3  9/8/2023 18:11:16   A60205220073     Sunaina Arora   B.Tech-CSE
# 4  9/8/2023 18:37:37   A60205220083  Priyanshu Sengar   B.Tech-CSE
#
#             Applied for  Certification Done - Big Data   \
# 0  Data Science Engineer                             No
# 1  Data Science Engineer                             No
# 2  Data Science Engineer                             No
# 3  Data Science Engineer                             No
# 4  Data Science Engineer                             No
#
#   Certification Done - Data Science  Training Done - Data Science   \
# 0                                YES                           YES
# 1                                YES                           YES
# ...

# %%
student.tail()
# Out:
#              Timestamp Enrollment No.   Student Name  Course Name   \
# 40  9/10/2023 22:19:37   A60205220084   Nidhi Kushwah   B.Tech-CSE
# 41  9/10/2023 22:43:29   A60205220041    Vineet Tomar   B.Tech-CSE
# 42  9/10/2023 23:27:54   A60205220154  Mansi Tripathi   B.Tech-CSE
# 43   9/11/2023 0:56:08   A60205220025    Khushi Yadav   B.Tech-CSE
# 44  9/11/2023 10:19:03   A60205220112   Prabhat Gupta   B.Tech-CSE
#
#              Applied for  Certification Done - Big Data   \
# 40  Data Science Engineer                             No
# 41  Data Science Engineer                             No
# 42  Data Science Engineer                             No
# 43  Data Science Engineer                             No
# 44  Data Science Engineer                             No
#
#    Certification Done - Data Science  Training Done - Data Science   \
# 40                                YES                            No
# 41                                 No                           YES
# ...

# %%
student.isnull().sum()
# Out:
# Timestamp                                                                                                            0
# Enrollment No.                                                                                                       0
# Student Name                                                                                                         0
# Course Name                                                                                                          0
# Applied for                                                                                                          0
# Certification Done - Big Data                                                                                        0
# Certification Done - Data Science                                                                                    0
# Training Done - Data Science                                                                                         0
# ...

# %%
# class_10_students = student[student['Class'] == '10th']

# Sort the Class 10th students by Percentage in descending order
sorted_students_12th =student.sort_values(by='12th%', ascending=False)

# %%
sorted_students_12th.head()
# Out:
#              Timestamp Enrollment No.      Student Name  Course Name   \
# 36  9/10/2023 19:12:53   A60205220004   T. J. Prakruthi    B.Tech-CSE
# 23   9/9/2023 21:05:28   A60205220110            Md Azam   B.Tech-CSE
# 12   9/8/2023 22:49:36   A60204821015   Garvita Singhal           BCA
# 31  9/10/2023 11:10:55   A60205220111       Aastha Singh   B.Tech-CSE
# 27   9/10/2023 9:08:47   A60205220180  Abhay Singh Tomar   B.Tech-CSE
#
#              Applied for  Certification Done - Big Data   \
# 36  Data Science Engineer                             No
# 23  Data Science Engineer                             No
# 12  Data Science Engineer                             No
# 31  Data Science Engineer                             No
# 27  Data Science Engineer                             No
#
#    Certification Done - Data Science  Training Done - Data Science   \
# 36                                YES                            No
# ...

# %%
sorted_students_12th.tail()
# Out:
#              Timestamp Enrollment No.     Student Name  Course Name   \
# 11   9/8/2023 21:36:08   A60205220075  Akshita Tripathi   B.Tech-CSE
# 40  9/10/2023 22:19:37   A60205220084     Nidhi Kushwah   B.Tech-CSE
# 6    9/8/2023 18:57:56   A60205220130      Mukul Bindal   B.Tech-CSE
# 28   9/10/2023 9:32:43   A60205220012      Harsh Rajput   B.Tech-CSE
# 10   9/8/2023 20:53:57   A60205220145   Ankita Upadhyay   B.Tech-CSE
#
#              Applied for  Certification Done - Big Data   \
# 11  Data Science Engineer                             No
# 40  Data Science Engineer                             No
# 6   Data Science Engineer                             No
# 28  Data Science Engineer                             No
# 10  Data Science Engineer                             No
#
#    Certification Done - Data Science  Training Done - Data Science   \
# 11                                YES                           YES
# ...

# %%
sorted_students_10th =student.sort_values(by='10th%', ascending=False)

# %%
sorted_students_10th.head()
# Out:
#              Timestamp Enrollment No.        Student Name  Course Name   \
# 29   9/10/2023 9:49:12  A60205220020   Divyanshi Sikarwar    B.Tech-CSE
# 2    9/8/2023 17:50:23   A60205220095       Shashank Dixit   B.Tech-CSE
# 8    9/8/2023 19:45:50   A60205220047  Akanksha Srivastava   B.Tech-CSE
# 4    9/8/2023 18:37:37   A60205220083     Priyanshu Sengar   B.Tech-CSE
# 31  9/10/2023 11:10:55   A60205220111         Aastha Singh   B.Tech-CSE
#
#              Applied for  Certification Done - Big Data   \
# 29  Data Science Engineer                             No
# 2   Data Science Engineer                             No
# 8       Big Data Engineer                            YES
# 4   Data Science Engineer                             No
# 31  Data Science Engineer                             No
#
#    Certification Done - Data Science  Training Done - Data Science   \
# 29                                YES                           YES
# ...

# %%
sorted_students_10th.tail()
# Out:
#              Timestamp Enrollment No.     Student Name  Course Name   \
# 37  9/10/2023 20:14:32   A60205220019    HARSHIT SHARMA   B.Tech-CSE
# 11   9/8/2023 21:36:08   A60205220075  Akshita Tripathi   B.Tech-CSE
# 28   9/10/2023 9:32:43   A60205220012      Harsh Rajput   B.Tech-CSE
# 6    9/8/2023 18:57:56   A60205220130      Mukul Bindal   B.Tech-CSE
# 36  9/10/2023 19:12:53   A60205220004  T. J. Prakruthi    B.Tech-CSE
#
#              Applied for  Certification Done - Big Data   \
# 37  Data Science Engineer                             No
# 11  Data Science Engineer                             No
# 28  Data Science Engineer                             No
# 6   Data Science Engineer                             No
# 36  Data Science Engineer                             No
#
#    Certification Done - Data Science  Training Done - Data Science   \
# 37                                 No                           YES
# ...

# %%
student['Certification Done - Big Data ']
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
# 5      No
# 6      No
# 7      No
# 8     YES
# 9      No
# 10     No
# 11     No
# 12     No
# 13     No
# 14     No
# 15     No
# 16    YES
# 17     No
# 18     No
# 19     No
# 20     No
# 21     No
# 22     No
# 23     No
# 24     No
# 25     No
# 26     No
# 27     No
# 28     No
# 29     No
# 30     No
# 31     No
# 32    YES
# 33    YES
# 34     No
# 35     No
# 36     No
# 37     No
# 38     No
# 39     No
# 40     No
# 41     No
# 42     No
# 43     No
# 44     No
# Name: Certification Done - Big Data , dtype: object

# %%
# Filter the students who have done certification in big data
students_big_data_cert =student[student['Certification Done - Big Data '] == 'YES']['Student Name ']

# Displaying the names of students who have done certification in Big Data
print("Students who have done certification in Big Data:")
print(students_big_data_cert)
# Out:
# Students who have done certification in Big Data:
# 8       Akanksha Srivastava
# 16    Karthikeya Maringanti
# 32           Gaurav Singhal
# 33      Nikhil Singh Dhakad
# Name: Student Name , dtype: object

# %%
# Filter the students who have done certification in data science
students_data_Science_cert =student[student['Certification Done - Data Science '] == 'YES']['Student Name ']

# Displaying the names of students who have done certification in Data Science
print("Students who have done certification in Big Data:")
print(students_data_Science_cert)
# Out:
# Students who have done certification in Big Data:
# 0           Pradhumn Mittal
# 1            Abhishek Mishra
# 2             Shashank Dixit
# 3              Sunaina Arora
# 4           Priyanshu Sengar
# 5       Harsh Vardhan Rathod
# 6               Mukul Bindal
# 7        Prashant Sai Kalepu
# 9                 Aryan Soni
# 10           Ankita Upadhyay
# 11          Akshita Tripathi
# 12          Garvita Singhal
# 13           Suryansh Mishra
# 14           Priyansh Sharma
# 15             Rahul Choubey
# 17              Rajat Gupta
# 18    Akhand Pratap Sikarwar
# 19    Kinshuk Dayal Saraswat
# 20                Aman Singh
# 21             Priyal Gupta
# 22              Naman Mishra
# 23                   Md Azam
# 24             Pradeep Rawat
# 25                 Arya Nair
# 27         Abhay Singh Tomar
# 29       Divyanshi Sikarwar
# 31              Aastha Singh
# 32            Gaurav Singhal
# 34                Rohit Jain
# 35             Mohit Argade
# ...

# %%
# Filter the students who have done training  in big data
students_big_data_train =student[student['Training Done - Big Data '] == 'YES']['Student Name ']

# Displaying the names of students who have done training in Big Data
print("Students who have done Training  in Big Data:")
print(students_big_data_train)
# Out:
# Students who have done Training  in Big Data:
# 8       Akanksha Srivastava
# 10          Ankita Upadhyay
# 16    Karthikeya Maringanti
# 32           Gaurav Singhal
# 33      Nikhil Singh Dhakad
# Name: Student Name , dtype: object

# %%
# Filter the students who have done training  in data Science
students_data_science_train =student[student['Training Done - Data Science '] == 'YES']['Student Name ']

# Displaying the names of students who have done training in Data Science
print("Students who have done Training  in Data Science:")
print(students_big_data_cert)
# Out:
# Students who have done Training  in Data Science:
# 8       Akanksha Srivastava
# 16    Karthikeya Maringanti
# 32           Gaurav Singhal
# 33      Nikhil Singh Dhakad
# Name: Student Name , dtype: object

# %%
# student['Training Done - Data Science '] = student['Training Done - Data Science '].astype(bool)

#

# %%
# student['Training Done - Data Science ']

# %%
# student['Certification Done - Data Science '] = student['Training Done - Data Science '].astype(bool)

# %%
# student['Certification Done - Data Science ']

# %%
# Filter the dataset to include only students who have completed both the training and certification in data science
DS_CERT_TRAIN = student.loc[(student['Training Done - Data Science '] == 'YES') |
                                             (student['Certification Done - Data Science '] == 'YES')]

DS_CERT_TRAIN.head()
# Out:
#            Timestamp Enrollment No.     Student Name  Course Name   \
# 0  9/8/2023 16:39:07   A60205220099  Pradhumn Mittal    B.Tech-CSE
# 1  9/8/2023 17:40:38   A60205220141   Abhishek Mishra   B.Tech-CSE
# 2  9/8/2023 17:50:23   A60205220095    Shashank Dixit   B.Tech-CSE
# 3  9/8/2023 18:11:16   A60205220073     Sunaina Arora   B.Tech-CSE
# 4  9/8/2023 18:37:37   A60205220083  Priyanshu Sengar   B.Tech-CSE
#
#             Applied for  Certification Done - Big Data   \
# 0  Data Science Engineer                             No
# 1  Data Science Engineer                             No
# 2  Data Science Engineer                             No
# 3  Data Science Engineer                             No
# 4  Data Science Engineer                             No
#
#   Certification Done - Data Science  Training Done - Data Science   \
# 0                                YES                           YES
# 1                                YES                           YES
# ...

# %%
sorted_students_DS =DS_CERT_TRAIN.sort_values(by='Graduation %', ascending=False)

# %%
sorted_students_DS.head() # top 5 students who completed certification and training of data science
# Out:
#              Timestamp Enrollment No.     Student Name  Course Name   \
# 12   9/8/2023 22:49:36   A60204821015  Garvita Singhal           BCA
# 36  9/10/2023 19:12:53   A60205220004  T. J. Prakruthi    B.Tech-CSE
# 25   9/9/2023 22:09:26   A60204821001         Arya Nair          BCA
# 42  9/10/2023 23:27:54   A60205220154    Mansi Tripathi   B.Tech-CSE
# 1    9/8/2023 17:40:38   A60205220141   Abhishek Mishra   B.Tech-CSE
#
#              Applied for  Certification Done - Big Data   \
# 12  Data Science Engineer                             No
# 36  Data Science Engineer                             No
# 25  Data Science Engineer                             No
# 42  Data Science Engineer                             No
# 1   Data Science Engineer                             No
#
#    Certification Done - Data Science  Training Done - Data Science   \
# 12                                YES                            No
# ...

# %%
# Filter the dataset to include only students who have completed both the training and certification in data science
Training_Cert_BD = student.loc[(student['Training Done - Big Data '] == 'YES') |
                                             (student['Certification Done - Big Data '] == 'YES')]

Training_Cert_BD
# Out:
#              Timestamp Enrollment No.          Student Name  Course Name   \
# 8    9/8/2023 19:45:50   A60205220047    Akanksha Srivastava   B.Tech-CSE
# 10   9/8/2023 20:53:57   A60205220145        Ankita Upadhyay   B.Tech-CSE
# 16   9/9/2023 10:45:35   A60205220082  Karthikeya Maringanti   B.Tech-CSE
# 32  9/10/2023 12:15:31   A60205220102         Gaurav Singhal   B.Tech-CSE
# 33  9/10/2023 15:54:33   A60205220062    Nikhil Singh Dhakad   B.Tech-CSE
#
#              Applied for  Certification Done - Big Data   \
# 8       Big Data Engineer                            YES
# 10  Data Science Engineer                             No
# 16      Big Data Engineer                            YES
# 32  Data Science Engineer                            YES
# 33      Big Data Engineer                            YES
#
#    Certification Done - Data Science  Training Done - Data Science   \
# 8                                  No                           YES
# ...

# %%
Trainng_Cert_BD = student.loc[(student['Training Done - Big Data '] == 'YES') |
                                             (student['Certification Done - Big Data '] == 'YES')]

# Convert the `Training Done - Data Science ` column to boolean type
# Trainng_Cert_BD['Training Done - Big Data '] = data_of_india_bangladesh_pakistan['Training Done - Big Data '].astype(bool)

# Print the filtered dataset
print(Trainng_Cert_BD['Student Name '])
# Out:
# 8       Akanksha Srivastava
# 10          Ankita Upadhyay
# 16    Karthikeya Maringanti
# 32           Gaurav Singhal
# 33      Nikhil Singh Dhakad
# Name: Student Name , dtype: object

# %%
sorted_students_BD =Trainng_Cert_BD.sort_values(by='Graduation %', ascending=False)

# %%
Trainng_Cert_BD.head() #top 5 students who completed certifcation and training of big data
# Out:
#              Timestamp Enrollment No.          Student Name  Course Name   \
# 8    9/8/2023 19:45:50   A60205220047    Akanksha Srivastava   B.Tech-CSE
# 10   9/8/2023 20:53:57   A60205220145        Ankita Upadhyay   B.Tech-CSE
# 16   9/9/2023 10:45:35   A60205220082  Karthikeya Maringanti   B.Tech-CSE
# 32  9/10/2023 12:15:31   A60205220102         Gaurav Singhal   B.Tech-CSE
# 33  9/10/2023 15:54:33   A60205220062    Nikhil Singh Dhakad   B.Tech-CSE
#
#              Applied for  Certification Done - Big Data   \
# 8       Big Data Engineer                            YES
# 10  Data Science Engineer                             No
# 16      Big Data Engineer                            YES
# 32  Data Science Engineer                            YES
# 33      Big Data Engineer                            YES
#
#    Certification Done - Data Science  Training Done - Data Science   \
# 8                                  No                           YES
# ...
